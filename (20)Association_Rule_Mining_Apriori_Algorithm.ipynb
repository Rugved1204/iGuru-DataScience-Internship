# %%
# Association Rule Mining
# Association Rule Mining is a technique used to discover relationships between items in large datasets.
# It helps answer questions like: "Which products are frequently bought together?"
# It's widely used in:
# ✔ Market Basket Analysis (e.g., "People who buy bread often buy butter.")
# ✔ Recommender Systems (e.g., Amazon’s "Customers who bought this also bought…")
# ✔ Fraud Detection (finding unusual transaction patterns)

# Apriori Algorithm Overview
# The Apriori Algorithm is the most popular technique for association rule mining.
# It works in two main steps:
# 1️.) Find Frequent Itemsets
#    - Identify sets of items that appear together frequently in transactions.
#    - This is based on Support (minimum occurrence threshold).
# 2️.) Generate Association Rules
#    - Find relationships between these frequent itemsets.
#    - Rules are evaluated using Confidence and Lift.

# Key Metrics in Apriori:
# Support = (Transactions with A and B) / (Total Transactions) → Measures how often an itemset appears in transactions.
# Confidence = (Transactions with A and B) / (Transactions with A) → Measures the probability that B is bought given A.
# Lift = (Confidence of (A → B)) / (Expected Confidence if A and B were independent) → Measures the strength of the association.
# High Lift (>1) → A & B are positively correlated (strong relationship).
# Lift = 1 → No correlation.
# Lift <1 → A & B are negatively correlated.

# %%
pip install apriori
# Out:
# Requirement already satisfied: apriori in /usr/local/lib/python3.11/dist-packages (1.0.0)

# %%
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
import seaborn as sns
import matplotlib.pyplot as plt

# %%
store_data = pd.read_csv('store_data.csv')

# %%
store_data.head()
# Out:
#            shrimp    almonds     avocado    vegetables mix green grapes  \
# 0         burgers  meatballs        eggs               NaN          NaN
# 1         chutney        NaN         NaN               NaN          NaN
# 2          turkey    avocado         NaN               NaN          NaN
# 3   mineral water       milk  energy bar  whole wheat rice    green tea
# 4  low fat yogurt        NaN         NaN               NaN          NaN
#
#   whole weat flour yams cottage cheese energy drink tomato juice  \
# 0              NaN  NaN            NaN          NaN          NaN
# 1              NaN  NaN            NaN          NaN          NaN
# 2              NaN  NaN            NaN          NaN          NaN
# 3              NaN  NaN            NaN          NaN          NaN
# 4              NaN  NaN            NaN          NaN          NaN
#
#   low fat yogurt green tea honey salad mineral water salmon antioxydant juice  \
# 0            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 1            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 2            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 3            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 4            NaN       NaN   NaN   NaN           NaN    NaN               NaN
#
#   frozen smoothie spinach  olive oil
# 0             NaN     NaN        NaN
# 1             NaN     NaN        NaN
# 2             NaN     NaN        NaN
# 3             NaN     NaN        NaN
# 4             NaN     NaN        NaN

# %%
store_data = pd.read_csv('store_data.csv', header=None)

# %%
store_data.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN

# %%
# Data Proprocessing
records = []
for i in range(0, 7501):
    records.append([str(store_data.values[i,j]) for j in range(0, 20)])

# %%
# !pip install mlxtend --quiet
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
df = pd.DataFrame(records)
df_encoded = pd.get_dummies(df.stack()).groupby(level=0).max()

# Apply Apriori Algorithm
frequent_itemsets = apriori(df_encoded, min_support=0.0045, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2)
rules = rules[(rules["lift"] >= 3) & (rules["confidence"] >= 0.2)]
for index, row in rules.iterrows():
    antecedents = ', '.join(list(row['antecedents']))
    consequents = ', '.join(list(row['consequents']))
    print(f"Rule: {antecedents} -> {consequents}")
    print(f"Support: {row['support']}")
    print(f"Confidence: {row['confidence']}")
    print(f"Lift: {row['lift']}")
    print("="*40)
# Out:
# Rule: light cream -> chicken
# Support: 0.004532728969470737
# Confidence: 0.29059829059829057
# Lift: 4.84395061728395
# ========================================
# Rule: mushroom cream sauce -> escalope
# Support: 0.005732568990801226
# Confidence: 0.3006993006993007
# Lift: 3.790832696715049
# ========================================
# Rule: pasta -> escalope
# Support: 0.005865884548726837
# Confidence: 0.3728813559322034
# Lift: 4.700811850163794
# ========================================
# Rule: herb & pepper -> ground beef
# Support: 0.015997866951073192
# Confidence: 0.3234501347708895
# Lift: 3.2919938411349285
# ========================================
# Rule: tomato sauce -> ground beef
# Support: 0.005332622317024397
# Confidence: 0.3773584905660377
# Lift: 3.840659481324083
# ========================================
# Rule: whole wheat pasta -> olive oil
# Support: 0.007998933475536596
# Confidence: 0.2714932126696833
# Lift: 4.122410097642296
# ========================================
# Rule: pasta -> shrimp
# Support: 0.005065991201173177
# Confidence: 0.3220338983050847
# Lift: 4.506672147735896
# ========================================
# Rule: light cream, nan -> chicken
# Support: 0.004532728969470737
# Confidence: 0.29059829059829057
# Lift: 4.84395061728395
# ========================================
# Rule: light cream -> chicken, nan
# Support: 0.004532728969470737
# Confidence: 0.29059829059829057
# Lift: 4.84395061728395
# ========================================
# Rule: chocolate, frozen vegetables -> shrimp
# Support: 0.005332622317024397
# Confidence: 0.23255813953488375
# Lift: 3.2545123221103784
# ========================================
# Rule: chocolate, shrimp -> frozen vegetables
# Support: 0.005332622317024397
# Confidence: 0.29629629629629634
# Lift: 3.1084175084175087
# ========================================
# Rule: spaghetti, cooking oil -> ground beef
# Support: 0.004799360085321957
# Confidence: 0.3025210084033613
# Lift: 3.0789824749438446
# ========================================
# Rule: cooking oil, ground beef -> spaghetti
# Support: 0.004799360085321957
# Confidence: 0.5714285714285714
# Lift: 3.2819951870487856
# ========================================
# Rule: nan, mushroom cream sauce -> escalope
# Support: 0.005732568990801226
# Confidence: 0.3006993006993007
# Lift: 3.790832696715049
# ========================================
# Rule: mushroom cream sauce -> escalope, nan
# Support: 0.005732568990801226
# Confidence: 0.3006993006993007
# Lift: 3.790832696715049
# ========================================
# Rule: nan, pasta -> escalope
# Support: 0.005865884548726837
# Confidence: 0.3728813559322034
# Lift: 4.700811850163794
# ========================================
# Rule: pasta -> escalope, nan
# Support: 0.005865884548726837
# Confidence: 0.3728813559322034
# Lift: 4.700811850163794
# ========================================
# Rule: spaghetti, frozen vegetables -> ground beef
# Support: 0.008665511265164644
# Confidence: 0.31100478468899523
# Lift: 3.165328208890303
# ========================================
# Rule: milk, frozen vegetables -> olive oil
# Support: 0.004799360085321957
# Confidence: 0.20338983050847456
# Lift: 3.088314005352364
# ========================================
# Rule: frozen vegetables, olive oil -> milk
# Support: 0.004799360085321957
# Confidence: 0.4235294117647058
# Lift: 3.2684095860566447
# ========================================
# Rule: mineral water, shrimp -> frozen vegetables
# Support: 0.007199040127982935
# Confidence: 0.30508474576271183
# Lift: 3.200616332819722
# ========================================
# Rule: spaghetti, frozen vegetables -> olive oil
# Support: 0.005732568990801226
# Confidence: 0.20574162679425836
# Lift: 3.1240241752707125
# ========================================
# Rule: spaghetti, frozen vegetables -> shrimp
# Support: 0.005999200106652446
# Confidence: 0.21531100478468898
# Lift: 3.0131489680782684
# ========================================
# Rule: spaghetti, frozen vegetables -> tomatoes
# Support: 0.006665777896280496
# Confidence: 0.23923444976076558
# Lift: 3.4980460188216425
# ========================================
# Rule: spaghetti, tomatoes -> frozen vegetables
# Support: 0.006665777896280496
# Confidence: 0.3184713375796179
# Lift: 3.341053850607991
# ========================================
# Rule: spaghetti, grated cheese -> ground beef
# Support: 0.005332622317024397
# Confidence: 0.3225806451612903
# Lift: 3.283144395325426
# ========================================
# Rule: mineral water, herb & pepper -> ground beef
# Support: 0.006665777896280496
# Confidence: 0.39062500000000006
# Lift: 3.975682666214383
# ========================================
# Rule: nan, herb & pepper -> ground beef
# Support: 0.015997866951073192
# Confidence: 0.3234501347708895
# Lift: 3.2919938411349285
# ========================================
# Rule: herb & pepper -> ground beef, nan
# Support: 0.015997866951073192
# Confidence: 0.3234501347708895
# Lift: 3.2919938411349285
# ========================================
# Rule: spaghetti, herb & pepper -> ground beef
# Support: 0.006399146780429276
# Confidence: 0.3934426229508197
# Lift: 4.004359721511667
# ========================================
# Rule: milk, ground beef -> olive oil
# Support: 0.004932675643247567
# Confidence: 0.22424242424242427
# Lift: 3.40494417862839
# ========================================
# Rule: tomato sauce, nan -> ground beef
# Support: 0.005332622317024397
# Confidence: 0.3773584905660377
# Lift: 3.840659481324083
# ========================================
# Rule: tomato sauce -> ground beef, nan
# Support: 0.005332622317024397
# Confidence: 0.3773584905660377
# Lift: 3.840659481324083
# ========================================
# Rule: ground beef, shrimp -> spaghetti
# Support: 0.005999200106652446
# Confidence: 0.5232558139534884
# Lift: 3.005315360233627
# ========================================
# Rule: spaghetti, milk -> olive oil
# Support: 0.007199040127982935
# Confidence: 0.20300751879699247
# Lift: 3.0825089038385434
# ========================================
# Rule: soup, mineral water -> olive oil
# Support: 0.005199306759098787
# Confidence: 0.22543352601156072
# Lift: 3.4230301186492245
# ========================================
# Rule: whole wheat pasta, nan -> olive oil
# Support: 0.007998933475536596
# Confidence: 0.2714932126696833
# Lift: 4.122410097642296
# ========================================
# Rule: whole wheat pasta -> nan, olive oil
# Support: 0.007998933475536596
# Confidence: 0.2714932126696833
# Lift: 4.13077198425009
# ========================================
# Rule: nan, pasta -> shrimp
# Support: 0.005065991201173177
# Confidence: 0.3220338983050847
# Lift: 4.506672147735896
# ========================================
# Rule: pasta -> nan, shrimp
# Support: 0.005065991201173177
# Confidence: 0.3220338983050847
# Lift: 4.515095833993347
# ========================================
# Rule: spaghetti, pancakes -> olive oil
# Support: 0.005065991201173177
# Confidence: 0.20105820105820105
# Lift: 3.0529100529100526
# ========================================
# Rule: chocolate, nan, frozen vegetables -> shrimp
# Support: 0.005332622317024397
# Confidence: 0.23255813953488375
# Lift: 3.2545123221103784
# ========================================
# Rule: chocolate, nan, shrimp -> frozen vegetables
# Support: 0.005332622317024397
# Confidence: 0.29629629629629634
# Lift: 3.1084175084175087
# ========================================
# Rule: chocolate, frozen vegetables -> nan, shrimp
# Support: 0.005332622317024397
# Confidence: 0.23255813953488375
# Lift: 3.260595522712454
# ========================================
# Rule: chocolate, shrimp -> nan, frozen vegetables
# Support: 0.005332622317024397
# Confidence: 0.29629629629629634
# Lift: 3.1084175084175087
# ========================================
# Rule: spaghetti, cooking oil, nan -> ground beef
# Support: 0.004799360085321957
# Confidence: 0.3025210084033613
# Lift: 3.0789824749438446
# ========================================
# Rule: cooking oil, ground beef, nan -> spaghetti
# Support: 0.004799360085321957
# Confidence: 0.5714285714285714
# Lift: 3.2819951870487856
# ========================================
# Rule: spaghetti, cooking oil -> ground beef, nan
# Support: 0.004799360085321957
# Confidence: 0.3025210084033613
# Lift: 3.0789824749438446
# ========================================
# Rule: cooking oil, ground beef -> spaghetti, nan
# Support: 0.004799360085321957
# Confidence: 0.5714285714285714
# Lift: 3.2819951870487856
# ========================================
# Rule: spaghetti, nan, frozen vegetables -> ground beef
# Support: 0.008665511265164644
# Confidence: 0.31100478468899523
# Lift: 3.165328208890303
# ========================================
# Rule: spaghetti, frozen vegetables -> ground beef, nan
# Support: 0.008665511265164644
# Confidence: 0.31100478468899523
# Lift: 3.165328208890303
# ========================================
# Rule: milk, spaghetti, mineral water -> frozen vegetables
# Support: 0.004532728969470737
# Confidence: 0.28813559322033894
# Lift: 3.0228043143297376
# ========================================
# Rule: milk, nan, frozen vegetables -> olive oil
# Support: 0.004799360085321957
# Confidence: 0.20338983050847456
# Lift: 3.088314005352364
# ========================================
# Rule: nan, frozen vegetables, olive oil -> milk
# Support: 0.004799360085321957
# Confidence: 0.4235294117647058
# Lift: 3.2684095860566447
# ========================================
# Rule: milk, frozen vegetables -> nan, olive oil
# Support: 0.004799360085321957
# Confidence: 0.20338983050847456
# Lift: 3.094578333963626
# ========================================
# Rule: frozen vegetables, olive oil -> milk, nan
# Support: 0.004799360085321957
# Confidence: 0.4235294117647058
# Lift: 3.2684095860566447
# ========================================
# Rule: nan, mineral water, shrimp -> frozen vegetables
# Support: 0.007199040127982935
# Confidence: 0.3068181818181818
# Lift: 3.218801652892562
# ========================================
# Rule: mineral water, shrimp -> nan, frozen vegetables
# Support: 0.007199040127982935
# Confidence: 0.30508474576271183
# Lift: 3.200616332819722
# ========================================
# Rule: spaghetti, nan, frozen vegetables -> olive oil
# Support: 0.005732568990801226
# Confidence: 0.20574162679425836
# Lift: 3.1240241752707125
# ========================================
# Rule: spaghetti, frozen vegetables -> nan, olive oil
# Support: 0.005732568990801226
# Confidence: 0.20574162679425836
# Lift: 3.1303609383037156
# ========================================
# Rule: spaghetti, nan, frozen vegetables -> shrimp
# Support: 0.005999200106652446
# Confidence: 0.21531100478468898
# Lift: 3.0131489680782684
# ========================================
# Rule: spaghetti, frozen vegetables -> nan, shrimp
# Support: 0.005999200106652446
# Confidence: 0.21531100478468898
# Lift: 3.0187810222242093
# ========================================
# Rule: spaghetti, nan, frozen vegetables -> tomatoes
# Support: 0.006665777896280496
# Confidence: 0.23923444976076558
# Lift: 3.4980460188216425
# ========================================
# Rule: spaghetti, nan, tomatoes -> frozen vegetables
# Support: 0.006665777896280496
# Confidence: 0.3184713375796179
# Lift: 3.341053850607991
# ========================================
# Rule: spaghetti, frozen vegetables -> nan, tomatoes
# Support: 0.006665777896280496
# Confidence: 0.23923444976076558
# Lift: 3.4980460188216425
# ========================================
# Rule: spaghetti, tomatoes -> nan, frozen vegetables
# Support: 0.006665777896280496
# Confidence: 0.3184713375796179
# Lift: 3.341053850607991
# ========================================
# Rule: spaghetti, nan, grated cheese -> ground beef
# Support: 0.005332622317024397
# Confidence: 0.3225806451612903
# Lift: 3.283144395325426
# ========================================
# Rule: spaghetti, grated cheese -> ground beef, nan
# Support: 0.005332622317024397
# Confidence: 0.3225806451612903
# Lift: 3.283144395325426
# ========================================
# Rule: nan, mineral water, herb & pepper -> ground beef
# Support: 0.006665777896280496
# Confidence: 0.39062500000000006
# Lift: 3.975682666214383
# ========================================
# Rule: mineral water, herb & pepper -> ground beef, nan
# Support: 0.006665777896280496
# Confidence: 0.39062500000000006
# Lift: 3.975682666214383
# ========================================
# Rule: spaghetti, nan, herb & pepper -> ground beef
# Support: 0.006399146780429276
# Confidence: 0.3934426229508197
# Lift: 4.004359721511667
# ========================================
# Rule: spaghetti, herb & pepper -> ground beef, nan
# Support: 0.006399146780429276
# Confidence: 0.3934426229508197
# Lift: 4.004359721511667
# ========================================
# Rule: milk, ground beef, nan -> olive oil
# Support: 0.004932675643247567
# Confidence: 0.22424242424242427
# Lift: 3.40494417862839
# ========================================
# Rule: milk, ground beef -> nan, olive oil
# Support: 0.004932675643247567
# Confidence: 0.22424242424242427
# Lift: 3.4118507591124225
# ========================================
# Rule: ground beef, nan, shrimp -> spaghetti
# Support: 0.005999200106652446
# Confidence: 0.5232558139534884
# Lift: 3.005315360233627
# ========================================
# Rule: ground beef, shrimp -> spaghetti, nan
# Support: 0.005999200106652446
# Confidence: 0.5232558139534884
# Lift: 3.005315360233627
# ========================================
# Rule: spaghetti, nan, milk -> olive oil
# Support: 0.007199040127982935
# Confidence: 0.20300751879699247
# Lift: 3.0825089038385434
# ========================================
# Rule: spaghetti, milk -> nan, olive oil
# Support: 0.007199040127982935
# Confidence: 0.20300751879699247
# Lift: 3.088761457396025
# ========================================
# Rule: soup, nan, mineral water -> olive oil
# Support: 0.005199306759098787
# Confidence: 0.22543352601156072
# Lift: 3.4230301186492245
# ========================================
# Rule: soup, mineral water -> nan, olive oil
# Support: 0.005199306759098787
# Confidence: 0.22543352601156072
# Lift: 3.429973384609973
# ========================================
# Rule: spaghetti, pancakes, nan -> olive oil
# Support: 0.005065991201173177
# Confidence: 0.20105820105820105
# Lift: 3.0529100529100526
# ========================================
# Rule: spaghetti, pancakes -> nan, olive oil
# Support: 0.005065991201173177
# Confidence: 0.20105820105820105
# Lift: 3.0591025682303568
# ========================================
# Rule: milk, spaghetti, nan, mineral water -> frozen vegetables
# Support: 0.004532728969470737
# Confidence: 0.28813559322033894
# Lift: 3.0228043143297376
# ========================================
# Rule: milk, spaghetti, mineral water -> nan, frozen vegetables
# Support: 0.004532728969470737
# Confidence: 0.28813559322033894
# Lift: 3.0228043143297376
# ========================================
