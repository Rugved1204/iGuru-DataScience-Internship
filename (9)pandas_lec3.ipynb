# %%
# how to use pandas to deal with different-different file format like:
# Read an Excel-file
# Read an CSV-file
# Read an JSON-file
# Read an txt-file
# how to upload local file


import pandas as pd

# %%
# Read an Excel-file
# read_excel() - reads data from sheet1 by default

data = pd.read_excel('https://raw.githubusercontent.com/yash240990/Python/master/sampleExcelData.xlsx')
data
# Out:
#        id first_name   last_name                      email    gender  \
# 0       1      Merle     Draisey  mdraisey0@squarespace.com  Bigender
# 1       2      Casey      Sheach    csheach1@deviantart.com      Male
# 2       3      Darya     Leivers        dleivers2@imgur.com    Female
# 3       4     Fancie  Casebourne          fcasebourne3@g.co    Female
# 4       5    Jenilee    Vsanelli         jvsanelli4@fc2.com    Female
# ..    ...        ...         ...                        ...       ...
# 995   996     Lutero       Yurov            lyurovrn@un.org      Male
# 996   997      Verla       Peery           vpeeryro@com.com    Female
# 997   998       Fran     Langran          flangranrp@ft.com      Male
# 998   999      Gabbi     Cummins        gcumminsrq@jugem.jp    Female
# 999  1000   Gloriane        Marc   gmarcrr@businessweek.com    Female
#
#           ip_address
# 0       20.70.199.51
# 1    226.126.229.167
# 2     247.209.88.235
# 3     172.34.162.239
# ...

# %%
# how to know how many sheets are present in excel file?

excelfile = pd.ExcelFile('https://raw.githubusercontent.com/yash240990/Python/master/sampleExcelData.xlsx')
excelfile.sheet_names
# Out:
# ['data', 'Sheet2']

# %%
# To access sheet other than first sheet

data = pd.read_excel(excelfile, 'Sheet2')
data
# Out:
#    first_name    last_name                                 email
# 0       Merle      Draisey             mdraisey0@squarespace.com
# 1       Casey       Sheach               csheach1@deviantart.com
# 2       Darya      Leivers                   dleivers2@imgur.com
# 3      Fancie   Casebourne                     fcasebourne3@g.co
# 4     Jenilee     Vsanelli                    jvsanelli4@fc2.com
# 5    Charmian    Drinkhall       cdrinkhall5@theglobeandmail.com
# 6     Janessa       Kivell                 jkivell6@linkedin.com
# 7       Mirna       Heinsh                  mheinsh7@spotify.com
# 8       Darby          Lax                   dlax8@people.com.cn
# 9       Meryl        Riehm                 mriehm9@princeton.edu
# 10       Anne        Brody                    abrodya@sphinn.com
# 11       Puff    Langsbury             plangsburyb@canalblog.com
# 12       Tina      Gregoli                  tgregolic@sfgate.com
# ...

# %%
# Read a CSV file

data = pd.read_csv('https://raw.githubusercontent.com/yash240990/Python/master/Position_Salaries.csv')
data
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
# Reading data in txt delimited format

data = pd.read_csv('https://www.inf.ed.ac.uk/teaching/courses/inf2b/labs/iris.txt', sep='\t')
data
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Species
# 0             5.1          3.5           1.4          0.2        1
# 1             4.9          3.0           1.4          0.2        1
# 2             4.7          3.2           1.3          0.2        1
# 3             4.6          3.1           1.5          0.2        1
# 4             5.0          3.6           1.4          0.2        1
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        3
# 146           6.3          2.5           5.0          1.9        3
# 147           6.5          3.0           5.2          2.0        3
# 148           6.2          3.4           5.4          2.3        3
# 149           5.9          3.0           5.1          1.8        3
#
# [150 rows x 5 columns]

# %%
# How to read json format

data = pd.read_json('https://raw.githubusercontent.com/yash240990/Python/master/simple.json')
data
# Out:
#      id   name  math  physics  chemistry
# 0  A001    Tom    60       66         61
# 1  A002  James    89       76         51
# 2  A003  Jenny    79       90         78

# %%
# How to work with local files
# website to download dummy excel files - mockaroo

from google.colab import files
uploaded = files.upload()  # upload widget
# Out:
#      <input type="file" id="files-be0e1f3c-8fb9-4a29-a8fc-03e02fc22787" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-be0e1f3c-8fb9-4a29-a8fc-03e02fc22787">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('MOCK_DATA.csv')
data
# Out:
#        id first_name    last_name                          email  gender  \
# 0       1     Dannel      Delmage      ddelmage0@studiopress.com    Male
# 1       2     Reggie       Beeble       rbeeble1@stumbleupon.com  Female
# 2       3    Dalenna         Ruby               druby2@goo.ne.jp  Female
# 3       4     Garret       Gatsby          ggatsby3@amazon.co.jp    Male
# 4       5      Daria    Pickthorn      dpickthorn4@homestead.com  Female
# ..    ...        ...          ...                            ...     ...
# 995   996    Helaina    Milverton          hmilvertonrn@usda.gov  Female
# 996   997       Amby        Zoane           azoanero@yahoo.co.jp    Male
# 997   998      Corey  Portchmouth  cportchmouthrp@indiatimes.com  Female
# 998   999   Marchall     Jeffryes    mjeffryesrq@istockphoto.com    Male
# 999  1000      Nadya     Wyldbore          nwyldborerr@amazon.de  Female
#
#                      city  salary
# 0            Ponta do Sol   40145
# ...
