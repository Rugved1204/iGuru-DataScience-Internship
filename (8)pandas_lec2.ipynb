# %%
import pandas as pd
import numpy as np

# %%
# datadrame = represent data in tabular form

emp_info = {'Id':[101,102,103] , 'Name':['John','Alex','Smith'] , 'Dept':['IT','Sales','Finance'] , 'Salary':[35000,45000,40000]}
print(emp_info)
# Out:
# {'Id': [101, 102, 103], 'Name': ['John', 'Alex', 'Smith'], 'Dept': ['IT', 'Sales', 'Finance'], 'Salary': [35000, 45000, 40000]}

# %%
data = pd.DataFrame(emp_info)
print(data)
print(type(data))

# %%
data
# Out:
# pandas.core.frame.DataFrame

# %%
emp_info = {'Id':[101,102,103] , 'Name':['John','Alex','Smith'] , 'Dept':['IT','Sales','Finance'] , 'Salary':[35000,45000,40000]}
data = pd.DataFrame(emp_info,index=['Emp1','Emp2','Emp3'])
data
# Out:
#        Id   Name     Dept  Salary
# Emp1  101   John       IT   35000
# Emp2  102   Alex    Sales   45000
# Emp3  103  Smith  Finance   40000

# %%
print(data.shape)
# Out:
# (3, 4)

# %%
print(data['Dept'].values)
# Out:
# ['IT' 'Sales' 'Finance']

# %%
data.columns
# Out:
# Index(['Id', 'Name', 'Dept', 'Salary'], dtype='object')

# %%
data[['Name','Dept']]
# Out:
#        Name     Dept
# Emp1   John       IT
# Emp2   Alex    Sales
# Emp3  Smith  Finance

# %%
# locate row

data.loc['Emp2']
# Out:
# Id          102
# Name       Alex
# Dept      Sales
# Salary    45000
# Name: Emp2, dtype: object

# %%
data.loc[['Emp2','Emp3']]
# Out:
#        Id   Name     Dept  Salary
# Emp2  102   Alex    Sales   45000
# Emp3  103  Smith  Finance   40000

# %%
# date range()
# yyyymmdd format

dates = pd.date_range('20250101',periods=10)
dates
# Out:
# DatetimeIndex(['2025-01-01', '2025-01-02', '2025-01-03', '2025-01-04',
#                '2025-01-05', '2025-01-06', '2025-01-07', '2025-01-08',
#                '2025-01-09', '2025-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.rand(10,4), index=dates)
df
# Out:
#                    0         1         2         3
# 2025-01-01  0.005649  0.811008  0.516353  0.347816
# 2025-01-02  0.691362  0.257527  0.387008  0.593205
# 2025-01-03  0.625427  0.087109  0.363771  0.943291
# 2025-01-04  0.327381  0.391763  0.140871  0.624714
# 2025-01-05  0.448098  0.930379  0.233699  0.761584
# 2025-01-06  0.394546  0.997198  0.901265  0.675528
# 2025-01-07  0.795341  0.856348  0.071353  0.105097
# 2025-01-08  0.198072  0.813904  0.603536  0.329129
# 2025-01-09  0.428670  0.389124  0.579577  0.675811
# 2025-01-10  0.879317  0.724030  0.223615  0.660557

# %%
emp = {'id':[1,2,3,4,5,6,7] , 'name':['A','B','C','D','E','F','G'] , 'salary':[1000,2654,2599,4785,6589,2541,2265] , 'dept': ['fin','sale','hr','it','market','sale','disc']}
data = pd.DataFrame(emp)
data
# Out:
#    id name  salary    dept
# 0   1    A    1000     fin
# 1   2    B    2654    sale
# 2   3    C    2599      hr
# 3   4    D    4785      it
# 4   5    E    6589  market
# 5   6    F    2541    sale
# 6   7    G    2265    disc

# %%
data[data['salary'] > 2500]
# Out:
#    id name  salary    dept
# 1   2    B    2654    sale
# 2   3    C    2599      hr
# 3   4    D    4785      it
# 4   5    E    6589  market
# 5   6    F    2541    sale

# %%
data[(data['salary'] > 2500) & (data['dept'] == 'sale')]
# Out:
#    id name  salary  dept
# 1   2    B    2654  sale
# 5   6    F    2541  sale
